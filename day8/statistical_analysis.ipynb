# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv("data.csv")
df.head()
# Out:
#    Mthly_HH_Income  Mthly_HH_Expense  No_of_Fly_Members  Emi_or_Rent_Amt  \
# 0             5000              8000                  3             2000
# 1             6000              7000                  2             3000
# 2            10000              4500                  2                0
# 3            10000              2000                  1                0
# 4            12500             12000                  2             3000
#
#    Annual_HH_Income Highest_Qualified_Member  No_of_Earning_Members
# 0             64200           Under-Graduate                      1
# 1             79920               Illiterate                      1
# 2            112800           Under-Graduate                      1
# 3             97200               Illiterate                      1
# 4            147000                 Graduate                      1

# %% [markdown]
# # MEAN
#
# The arithmetic mean is the sum of all of the numbers divided by the total amount of numbers.
#
#
# $$\mu=\frac {1}{n}\left(\sum _{i=1}^{n}{x_{i}}\right)=\frac {x_{1}+x_{2}+\cdots +x_{n}}{n}$$
#
# $\mu$ = Mean
#
# X1,X2,X3 = are the Data points
#
# n= total number of data points
#
#
#
# For example, the arithmetic mean of five values: 4, 36, 45, 50, 75 is:
#
# $$\mu = \frac {4+36+45+50+75}{5}={\frac {210}{5}}=42.$$

# %%
a=0
for i in df['Mthly_HH_Income']:
    a =a+i
mean=(a)/len(df['Mthly_HH_Income'])
print(mean)
# Out:
# 41558.0

# %%
df['Mthly_HH_Income'].mean()
# Out:
# 41558.0

# %% [markdown]
# # MEDIAN
#
# Median means the middle value of the given Data points,arranged in a order from lowest to highest values
#
# >When the **n** is even $${median} (x)=\frac {x_{n/2}+x_{(n/2)+1}}{2}^{th} term$$
#
#
#
#
#
#
# >When the **n** is odd
#
#
#  $${median} (x)=x_{(n+1)/2}$$
#
#
#
# ![medi.png](attachment:medi.png)

# %% [markdown]
# ## Median of "Annual_HH_Income"

# %%
median=sorted(df["Annual_HH_Income"])
n=0
for i in  median:
    n+=1
if n % 2 == 0: 
    median1 = median[n//2] 
    median2 = median[n//2 - 1] 
    median = (median1 + median2)/2
else: 
    median = median[n//2] 
print("Median is: " + str(median))
# Out:
# Median is: 447420.0

# %%
df["Annual_HH_Income"].median()
# Out:
# 447420.0

# %% [markdown]
# # MODE
#
# The number which occures more no of times in a set of numbers.
#
# for example:
#
#           1,2,811,3,4,4,6,6,9,811,811,75,9,811
#
# mode = 811
#
# ![images.png](attachment:images.png)

# %%
mode=df["Highest_Qualified_Member"]
mode.unique()
# Out:
# array(['Under-Graduate', 'Illiterate', 'Graduate', 'Post-Graduate',
#        'Professional'], dtype=object)

# %%
n=0
dic={}
for i in sorted(df["Highest_Qualified_Member"]):
    dic.setdefault(i,0)
    dic[i]+=1
    
for i,j in dic.items():
    if j==max(dic.values()):
        print(i)
# Out:
# Graduate

# %% [markdown]
# # Variance#
#
# variance is the average squared distance of the Data points from its mean
#
# **For Sample**:
# $$S^2 = \frac{\sum (x_i - \bar{x})^2}{n - 1}$$
# $S^2$	=	sample variance
#
# $x_i$	=	the value of the one observation
#
# $\bar{x}$	=	the mean value of all observations
#
# n	=	the number of observations
#
#
# **For Population**:
# $$\sigma^2 = \frac{\sum (x_i - \bar{x})^2}{N}$$
#
# **For example**
#              ![v4-460px-Calculate-Variance-Step-6-Version-3.jpg.jfif](attachment:v4-460px-Calculate-Variance-Step-6-Version-3.jpg.jfif)
#
# ![population-variance.png](attachment:population-variance.png)

# %%
n = len(df["Emi_or_Rent_Amt"])
mean = sum(df["Emi_or_Rent_Amt"])/n
deviations = [(x - mean) ** 2 for x in df["Emi_or_Rent_Amt"]]
v = sum(deviations)/n
print(v)
# Out:
# 38176400.0

# %%
df['Emi_or_Rent_Amt'].var()
# Out:
# 38955510.20408163

# %% [markdown]
# # Standard Deviation
#
# The standard deviation is the square root of variance.
#
#
# $$\sigma={\sqrt {\frac {\sum(x_{i}-{\mu})^{2}}{N}}}.$$
#
# $\sigma$	=	population standard deviation
#
# $N$	=	the size of the population
#
# $x_i$	=	each value from the population
#
# $\mu$	=	the population mean
#
#
# - low standard deviation indicates the values are close to their mean.
# - high standard deviation indicates the datapointa are wide spread acroos the mean.
#
#
#
# ![download.png](attachment:download.png)

# %%
n = len(df["Emi_or_Rent_Amt"])
mean = sum(df["Emi_or_Rent_Amt"])/n
deviations = [(x - mean) ** 2 for x in df["Emi_or_Rent_Amt"]]
std = (sum(deviations)/n)**0.5
print(std)
# Out:
# 6178.705366013175

# %% [markdown]
# # Correlation
#
# Correlation gives a measure of the degree of relationship between two variables.
#
# **Note**: Correlation does not indicate the causation of one variable to another, it only measures the strength of the relation between them.
#
# - There are mainly 2 types of correlation:
#
# <font color="blue">1. Pearson's Correlation</font>
#
# <font color="blue">2. Spearman Correlation</font>
#
#
# #### 1. Pearson's Correlation Coefficient(r):
#
# >The Pearson correlation coefficient, also known as r, R, or Pearson's r, is a measure of the strength and direction of the linear relationship between two variables that is defined as the covariance of the variables divided by the product of their standard deviations.$^{[1]}$
#
# $$ \rho=\frac{\sum (x_i - \bar{x}) (y_i - \bar{y})}{\sqrt{ \sum (x_i - \bar{x})^2 \sum (y_i - \bar{y})^2}}$$
#
#
# >$\rho$ = correlation coefficient
# >
# >$x_{i}$ = values of the x-variable in a sample
# >
# >$\bar{x}$ = mean of the values of the x-variable
# >
# >$y_{i}$ = values of the y-variable in a sample
# >
# >$\bar{y}$ = mean of the values of the y-variable
#
#
# - The $\rho$ can range between -1 to +1
# - if $\rho$<0 it indicates there is a negative linear relationship between the 2 variables.
# - if $\rho$>0 it indicates there is a positive linear relationship between the 2 variables.
# - if $\rho$ is nearer to $^+_-1$, it means there is a strong relationship between the 2 variables either positive or negative.
# - if $\rho$ is farther away or close to 0, it indicates there is a weaker or close to no significant relationship between the variables.
#
#
# $\color{green}{\text{Properties}}$
#
# - it is a parametric test
# - it measures only linear relationships.
# - mostly used for numerical variables.
#
#
#
# ![400px-Correlation_coefficient.png](attachment:400px-Correlation_coefficient.png)
#
# <font color="green">Assumptions</font>
#
# - **Level of measurement**: refers to each variable should be continuous.
#
# - **Related pairs**: refers to the pairs of variables, each observation should have a pair of values. So if the correlation was between weight and height, then each observation used should have both a weight and a height value.
#
# - **No outliers**: both the variables should be outlier free.
#
# - **Linearity**: a “straight line” relationship between the variable should be formed.
#
# - **Homoscedasticity**: the shape of the scatterplot should be tube-like in shape. If the shape is cone-like, then homoskedasticity would not be met.
#
# #### 2. Spearson's Correlation Coefficient(r):
#
# Spearson Correlation is measure of strength and monotonic relation between two variables.
#
# $$ \rho = 1- \frac{6 \sum d_i^2}{n(n^2 - 1)}$$
#
# >$\rho$ = Spearman's rank correlation coefficient
# >
# >$d_{i}$ = difference between the two ranks of each observation.
# >
# >n = number of observations
#
#
#
#
# ![spearman-1-small.png](attachment:spearman-1-small.png)
#
# ![P_value.png](attachment:P_value.png)

# %% [markdown]
# $$ \rho=\frac{\sum (x_i - \bar{x}) (y_i - \bar{y})}{\sqrt{ \sum (x_i - \bar{x})^2 \sum (y_i - \bar{y})^2}}$$

# %%
add=0
for i in df["Mthly_HH_Expense"]:
    add+=i
meanx=add/len(df["Mthly_HH_Expense"])
a=[]
for x in df["Mthly_HH_Expense"]:
    a.append(x-meanx)

# %%
add=0
for i in df["Annual_HH_Income"]:
    add+=i
meany=add/len(df["Annual_HH_Income"])
b=[]
for y in df["Annual_HH_Income"]:
    b.append(y-meany)

# %%
num=[]
for x,y in zip(a,b):
    num.append(x*y)

# %%
numerator=sum(num)

# %%
# for denominator
a_2=sum([i**2 for i in a])
b_2=sum([j**2 for j in b])
den=(a_2*b_2)**0.5
den
# Out:
# 189655045858.10098

# %%
correlation=numerator/den
correlation
# Out:
# 0.5912216295468027

# %%
df.corr()
# Out:
#                        Mthly_HH_Income  Mthly_HH_Expense  No_of_Fly_Members  \
# Mthly_HH_Income               1.000000          0.649215           0.448317
# Mthly_HH_Expense              0.649215          1.000000           0.639702
# No_of_Fly_Members             0.448317          0.639702           1.000000
# Emi_or_Rent_Amt               0.036976          0.405280           0.085808
# Annual_HH_Income              0.970315          0.591222           0.430868
# No_of_Earning_Members         0.347883          0.311915           0.597482
#
#                        Emi_or_Rent_Amt  Annual_HH_Income  \
# Mthly_HH_Income               0.036976          0.970315
# Mthly_HH_Expense              0.405280          0.591222
# No_of_Fly_Members             0.085808          0.430868
# Emi_or_Rent_Amt               1.000000          0.002716
# Annual_HH_Income              0.002716          1.000000
# No_of_Earning_Members        -0.097431          0.296679
#
# ...

# %% [markdown]
# # Normal Distribution
#
# Normal distribution is also known as the Gaussian distribution, is a probability distribution that is symmetric about the mean, showing that data near the mean are more frequent in occurrence than data far from the mean. In graph form, normal distribution will appear as a bell curve.
#
#
# ### Features of Normal Distribution
#
#    ***In normal distributation The mean, mode and median are all equal.***
#
# -  The curve is symmetric at the center (i.e. around the mean, μ).
# -  Exactly half of the values are to the left of center and exactly half the values are to the right.
# -  The total area under the curve is 1.
# -  The skewness for Normal distribution is == "0"
# -  The kurtosis for Normal distribution is == "3"
#
#  **Empirical rule for the normal distribution**
#
# ![standard-normal-distribution.jpg](attachment:standard-normal-distribution.jpg)
#
#    *from the above diagram
#
# - 68% of data lies in the one standard deviation away from the mean.
# - 95% of data lies in the two standard deviation away from the mean.
# - 99.7% of data lies in the three standard deviation away from the mean.
#
#
# ![probability-density-function-formula.png](attachment:probability-density-function-formula.png)
# f(x) = probability
#
# x = value of the variable
#
# μ = mean
#
# σ = standard deviation
#
# σ2 = variance

# %% [markdown]
# # Skewness
#
# In probability theory and statistics, skewness is a measure of the asymmetry of the probability distribution of a random variable. The skewness value can be **Positive**, **zero**, **Negative**.
#
#
# **Formula:**
#
#   ![Skewness-Formula-1.png](attachment:Skewness-Formula-1.png)
#
# - Xi is each individual score;
# - $\bar{X}$ is the population mean;
# - σ is the population standard deviation and
# - N is the population size.
#
# ### Positive Skewness: ###
#            - Positive Skewness means when the tail on the right side of the distribution is longer.
#            - The mean and median will be greater than the mode.
#
# ![page-61a.jpg](attachment:page-61a.jpg)
#
#
#
# ### Negative Skewness:###
#             - Negative Skewness is when the tail of the left side of the distribution is longer.
#             - The mean and median will be less than the mode.
# ![page-61B.jpg](attachment:page-61B.jpg)
#
# ### Skewness = "Zero":###
#
#             - The skewness for a normal distribution is zero, and any symmetric data should have a skewness near zero.
#  ![Skewness+=+0+%28symmetric+distribution%29crop.jpg](attachment:Skewness+=+0+%28symmetric+distribution%29crop.jpg)

# %%
sns.distplot(df["Annual_HH_Income"],hist=True,kde=True)
# Out:
# C:\Users\DUBBA SAI KIRAN\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Annual_HH_Income', ylabel='Density'>

# %% [markdown]
# - slightly Positive Skew

# %% [markdown]
# # Effect on Mean, Median and Mode due to Skewness
# - when the distribution is positively skewed, the mean greater than median greater than  mode.
# - when the distribution is negatively skewed, the mean less than median less than mode.
# - when the skewness is 0, it means it is a normal distribution and hence, mean = median = mode.
#
# ![168d619ae584c616adab5670ca38606b.jpg](attachment:168d619ae584c616adab5670ca38606b.jpg)

# %%
print('ab'.zfill(5))
# Out:
# 000ab

# %% [markdown]
# $\alpha^2$
# $\beta^2$
# $\gamma^2$

# %% [markdown]
# \$999$
# 999
